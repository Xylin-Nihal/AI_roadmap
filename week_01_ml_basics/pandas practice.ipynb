# %% [markdown]
# Pandas Practice

# %% [markdown]
# **Basic functions**

# %%
import pandas as pd
x=pd.read_csv("pokemon_data.csv")
#print(x.head(3))
#print(x.tail(3))
#print(x[["Name","Speed"]]) #double brackets are important
#print(x.iloc[1:5]) #to print the rows
#for index, row in x.iterrows():
 #   print(index, row['Name']) # to iter through rows
#x.loc[x['Type 1'] == "Grass"] #to display everything with the condition
## Read a specific location (R,C)
#print(x.iloc[2,1])
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# **sorting**

# %%
#x.sort_values(['Type 1', 'HP'], ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Making changes to the data

# %%
#x['Total'] = x['HP'] + x['Attack'] + x['Defense'] + x['Sp. Atk'] + x['Sp. Def'] + x['Speed']

# x = x.drop(columns=['Total'])

x['Total'] = x.iloc[:, 4:10].sum(axis=1)

cols = list(x.columns)
x = x[cols[0:4] + [cols[-1]]+cols[4:12]]

x.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
import openai

openai.api_key = "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"
openai.base_url = "https://api.groq.com/openai/v1"

response = openai.ChatCompletion.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": "Say hello!"}]
)

print(response.choices[0].message["content"])
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[2], line 6
#       3 openai.api_key = "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"
#       4 openai.base_url = "https://api.groq.com/openai/v1"
# ----> 6 response = openai.ChatCompletion.create(
#       7     model="llama-3.3-70b-versatile",
#       8     messages=[{"role": "user", "content": "Say hello!"}]
#       9 )
#      11 print(response.choices[0].message["content"])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\lib\_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# ...
